# %% [markdown]
# used to train a character recognition from input image using MobileNets.

# %%
# ignore warning 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras.layers import AveragePooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import glob
import numpy as np

# %% [markdown]
# visualize dataset

# %%
dataset_paths = glob.glob("dataset_characters/**/*.jpg")

cols=4
rows=3
fig = plt.figure(figsize=(10,8))
plt.rcParams.update({"font.size":14})
grid = gridspec.GridSpec(ncols=cols,nrows=rows,figure=fig)

# create a random list of images will be displayed
np.random.seed(45)
rand = np.random.randint(0,len(dataset_paths),size=(cols*rows))

# Plot image
for i in range(cols*rows):
    fig.add_subplot(grid[i])
    image = load_img(dataset_paths[rand[i]])
    label = dataset_paths[rand[i]].split(os.path.sep)[-2]
    plt.title('"{:s}"'.format(label))
    plt.axis(False)
    plt.imshow(image)

plt.savefig("Visualize_dataset.jpg",dpi=300)

# %% [markdown]
# data preprocessing

# %%
# Arange input data and corresponding labels
X=[]
labels=[]

for image_path in dataset_paths:
  label = image_path.split(os.path.sep)[-2]
  image=load_img(image_path,target_size=(80,80))
  image=img_to_array(image)

  X.append(image)
  labels.append(label)

X = np.array(X,dtype="float16")
labels = np.array(labels)

print("[INFO] Find {:d} images with {:d} classes".format(len(X),len(set(labels))))


# perform one-hot encoding on the labels
lb = LabelEncoder()
lb.fit(labels)
labels = lb.transform(labels)
y = to_categorical(labels)

# save label file so we can use in another script
np.save('license_character_classes.npy', lb.classes_)
# Out:
# [INFO] Find 37623 images with 36 classes

# %%
# split 10% of data as validation set
(trainX, testX, trainY, testY) = train_test_split(X, y, test_size=0.10, stratify=y, random_state=42)

# %%
# data augumentation
image_gen = ImageDataGenerator(rotation_range=10,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              shear_range=0.1,
                              zoom_range=0.1,
                              fill_mode="nearest"
                              )

# %% [markdown]
# Initialize MobileNets architecture with pre-trained weights

# %%
# Create our model with pre-trained MobileNetV2 architecture from imagenet
def create_model(lr=1e-4,decay=1e-4/25, training=False,output_shape=y.shape[1]):
    baseModel = MobileNetV2(weights="imagenet", 
                            include_top=False,
                            input_tensor=Input(shape=(80, 80, 3)))

    headModel = baseModel.output
    headModel = AveragePooling2D(pool_size=(3, 3))(headModel)
    headModel = Flatten(name="flatten")(headModel)
    headModel = Dense(128, activation="relu")(headModel)
    headModel = Dropout(0.5)(headModel)
    headModel = Dense(output_shape, activation="softmax")(headModel)
    
    model = Model(inputs=baseModel.input, outputs=headModel)
    
    if training:
        # define trainable lalyer
        for layer in baseModel.layers:
            layer.trainable = True
        # compile model
        optimizer = Adam(lr=lr, decay = decay)
        model.compile(loss="categorical_crossentropy", optimizer=optimizer,metrics=["accuracy"])    
        
    return model

# %%
# initilaize initial hyperparameter
INIT_LR = 1e-4
EPOCHS = 30

model = create_model(lr=INIT_LR, decay=INIT_LR/EPOCHS,training=True)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 34s 4us/step

# %% [markdown]
# Train Model

# %%
BATCH_SIZE = 64

my_checkpointer = [
                EarlyStopping(monitor='val_loss', patience=5, verbose=0),
                ModelCheckpoint(filepath="License_character_recognition.h5", verbose=1, save_weights_only=True)
                ]

result = model.fit(image_gen.flow(trainX, trainY, batch_size=BATCH_SIZE), 
                   steps_per_epoch=len(trainX) // BATCH_SIZE, 
                   validation_data=(testX, testY), 
                   validation_steps=len(testX) // BATCH_SIZE, 
                   epochs=EPOCHS, callbacks=my_checkpointer)
# Out:
# Epoch 1/30
# 529/529 [==============================] - ETA: 0s - loss: 1.4646 - accuracy: 0.6153
# Epoch 00001: saving model to License_character_recognition.h5
# 529/529 [==============================] - 301s 570ms/step - loss: 1.4646 - accuracy: 0.6153 - val_loss: 1.5178 - val_accuracy: 0.6330
# Epoch 2/30
# 529/529 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8909
# Epoch 00002: saving model to License_character_recognition.h5
# 529/529 [==============================] - 294s 555ms/step - loss: 0.4136 - accuracy: 0.8909 - val_loss: 0.4507 - val_accuracy: 0.8844
# Epoch 3/30
# 529/529 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.9204
# Epoch 00003: saving model to License_character_recognition.h5
# 529/529 [==============================] - 278s 525ms/step - loss: 0.2931 - accuracy: 0.9204 - val_loss: 0.2515 - val_accuracy: 0.9346
# Epoch 4/30
# 529/529 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9353
# Epoch 00004: saving model to License_character_recognition.h5
# 529/529 [==============================] - 324s 612ms/step - loss: 0.2342 - accuracy: 0.9353 - val_loss: 0.2036 - val_accuracy: 0.9455
# Epoch 5/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9435
# Epoch 00005: saving model to License_character_recognition.h5
# 529/529 [==============================] - 359s 678ms/step - loss: 0.1998 - accuracy: 0.9435 - val_loss: 0.1676 - val_accuracy: 0.9554
# Epoch 6/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9518
# Epoch 00006: saving model to License_character_recognition.h5
# 529/529 [==============================] - 306s 579ms/step - loss: 0.1671 - accuracy: 0.9518 - val_loss: 0.1443 - val_accuracy: 0.9564
# Epoch 7/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9554
# Epoch 00007: saving model to License_character_recognition.h5
# 529/529 [==============================] - 278s 525ms/step - loss: 0.1539 - accuracy: 0.9554 - val_loss: 0.1550 - val_accuracy: 0.9556
# Epoch 8/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9594
# Epoch 00008: saving model to License_character_recognition.h5
# 529/529 [==============================] - 280s 530ms/step - loss: 0.1356 - accuracy: 0.9594 - val_loss: 0.1221 - val_accuracy: 0.9649
# Epoch 9/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9629
# Epoch 00009: saving model to License_character_recognition.h5
# 529/529 [==============================] - 282s 533ms/step - loss: 0.1281 - accuracy: 0.9629 - val_loss: 0.1691 - val_accuracy: 0.9508
# Epoch 10/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9656
# Epoch 00010: saving model to License_character_recognition.h5
# 529/529 [==============================] - 285s 538ms/step - loss: 0.1167 - accuracy: 0.9656 - val_loss: 0.1269 - val_accuracy: 0.9607
# Epoch 11/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9655
# Epoch 00011: saving model to License_character_recognition.h5
# 529/529 [==============================] - 292s 552ms/step - loss: 0.1122 - accuracy: 0.9655 - val_loss: 0.1146 - val_accuracy: 0.9660
# Epoch 12/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9680
# Epoch 00012: saving model to License_character_recognition.h5
# 529/529 [==============================] - 281s 532ms/step - loss: 0.1037 - accuracy: 0.9680 - val_loss: 0.1099 - val_accuracy: 0.9631
# Epoch 13/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9699
# Epoch 00013: saving model to License_character_recognition.h5
# 529/529 [==============================] - 284s 537ms/step - loss: 0.0991 - accuracy: 0.9699 - val_loss: 0.1244 - val_accuracy: 0.9639
# Epoch 14/30
# 529/529 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9685
# Epoch 00014: saving model to License_character_recognition.h5
# 529/529 [==============================] - 285s 539ms/step - loss: 0.1010 - accuracy: 0.9685 - val_loss: 0.1057 - val_accuracy: 0.9684
# Epoch 15/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9715
# Epoch 00015: saving model to License_character_recognition.h5
# 529/529 [==============================] - 280s 529ms/step - loss: 0.0923 - accuracy: 0.9715 - val_loss: 0.1045 - val_accuracy: 0.9665
# Epoch 16/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9745
# Epoch 00016: saving model to License_character_recognition.h5
# 529/529 [==============================] - 283s 535ms/step - loss: 0.0819 - accuracy: 0.9745 - val_loss: 0.0918 - val_accuracy: 0.9729
# Epoch 17/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9735
# Epoch 00017: saving model to License_character_recognition.h5
# 529/529 [==============================] - 286s 540ms/step - loss: 0.0845 - accuracy: 0.9735 - val_loss: 0.1020 - val_accuracy: 0.9681
# Epoch 18/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9753
# Epoch 00018: saving model to License_character_recognition.h5
# 529/529 [==============================] - 283s 536ms/step - loss: 0.0810 - accuracy: 0.9753 - val_loss: 0.0949 - val_accuracy: 0.9692
# Epoch 19/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9745
# Epoch 00019: saving model to License_character_recognition.h5
# 529/529 [==============================] - 279s 528ms/step - loss: 0.0814 - accuracy: 0.9745 - val_loss: 0.0812 - val_accuracy: 0.9732
# Epoch 20/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9756
# Epoch 00020: saving model to License_character_recognition.h5
# 529/529 [==============================] - 284s 537ms/step - loss: 0.0755 - accuracy: 0.9756 - val_loss: 0.0919 - val_accuracy: 0.9702
# Epoch 21/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9769
# Epoch 00021: saving model to License_character_recognition.h5
# 529/529 [==============================] - 283s 535ms/step - loss: 0.0731 - accuracy: 0.9769 - val_loss: 0.0718 - val_accuracy: 0.9745
# Epoch 22/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9779
# Epoch 00022: saving model to License_character_recognition.h5
# 529/529 [==============================] - 279s 527ms/step - loss: 0.0708 - accuracy: 0.9779 - val_loss: 0.0966 - val_accuracy: 0.9710
# Epoch 23/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9786
# Epoch 00023: saving model to License_character_recognition.h5
# 529/529 [==============================] - 280s 530ms/step - loss: 0.0687 - accuracy: 0.9786 - val_loss: 0.0790 - val_accuracy: 0.9734
# Epoch 24/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9784
# Epoch 00024: saving model to License_character_recognition.h5
# 529/529 [==============================] - 279s 528ms/step - loss: 0.0686 - accuracy: 0.9784 - val_loss: 0.0959 - val_accuracy: 0.9724
# Epoch 25/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9795
# Epoch 00025: saving model to License_character_recognition.h5
# 529/529 [==============================] - 280s 529ms/step - loss: 0.0651 - accuracy: 0.9795 - val_loss: 0.1022 - val_accuracy: 0.9692
# Epoch 26/30
# 529/529 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9814
# Epoch 00026: saving model to License_character_recognition.h5
# 529/529 [==============================] - 278s 526ms/step - loss: 0.0572 - accuracy: 0.9814 - val_loss: 0.0914 - val_accuracy: 0.9732

# %% [markdown]
# Visualize traning result

# %%
fig = plt.figure(figsize=(14,5))
grid=gridspec.GridSpec(ncols=2,nrows=1,figure=fig)
fig.add_subplot(grid[0])
plt.plot(result.history['accuracy'], label='training accuracy')
plt.plot(result.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

fig.add_subplot(grid[1])
plt.plot(result.history['loss'], label='training loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

#plt.savefig("Training_result.jpg",dpi=300)

# %%
# save model architectur as json file
model_json = model.to_json()
with open("MobileNets_character_recognition.json", "w") as json_file:
  json_file.write(model_json)
